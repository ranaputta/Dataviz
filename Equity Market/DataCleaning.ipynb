# %%
import numpy as np
import pandas as pd
#import matplotlib.pylab as plt
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import matplotlib.animation as ani
sns.set()

# %%
datasp = pd.read_csv('HistoricalPrices_SP500_20Y.csv')
datasex = pd.read_csv('HistoricalPrices_Sensex_20Y.csv')
data50 = pd.read_csv('HistoricalPrices_Nifty50_20Y.csv')
datand = pd.read_csv('HistoricalPrices_Nasdaq_20Y.csv')
datadji = pd.read_csv('HistoricalPrices_DJIA_20Y.csv')
dataall = pd.read_csv('HistoricalPrices_Combines.csv')

# %%
datasp.head()
# Out:
#        Date     Open     High      Low    Close
# 0  1/3/2000  1455.22  1478.00  1438.36  1455.22
# 1  1/4/2000  1399.42  1455.22  1397.43  1399.42
# 2  1/5/2000  1402.11  1413.27  1377.68  1402.11
# 3  1/6/2000  1403.45  1411.90  1392.02  1403.45
# 4  1/7/2000  1441.47  1441.47  1400.53  1441.47

# %%
datasp['Date'] = pd.to_datetime(datasp['Date'])
datasex['Date'] = pd.to_datetime(datasex['Date'])
datasp.head()
# Out:
#         Date     Open     High      Low    Close
# 0 2000-01-03  1455.22  1478.00  1438.36  1455.22
# 1 2000-01-04  1399.42  1455.22  1397.43  1399.42
# 2 2000-01-05  1402.11  1413.27  1377.68  1402.11
# 3 2000-01-06  1403.45  1411.90  1392.02  1403.45
# 4 2000-01-07  1441.47  1441.47  1400.53  1441.47

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
datasex.tail()
# Out:
#            Date     Open     High      Low    Close
# 5173 2020-11-18 43978.58 44215.49 43785.78 44180.05
# 5174 2020-11-19 43902.24 44230.00 43518.11 43599.96
# 5175 2020-11-20 43732.14 44013.02 43453.75 43882.25
# 5176 2020-11-23 44164.17 44271.15 43747.22 44077.15
# 5177 2020-11-24 44341.19 44601.63 44247.12 44523.02

# %%
# Check for factors responsible in overall volume trade
fig, ax = plt.subplots (figsize = (10, 10))
corr_matrix = dataall.corr() # Perform default correlation using Pearson Method 

# Plot the correlation matrix in a heatmap to understand better
sns.heatmap(corr_matrix, xticklabels = corr_matrix.columns.values, yticklabels = corr_matrix.columns.values)
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">

# %%
# View the matrix in a table to identify the numerical values of strengths
corr_matrix
# Out:
#          SP500  NIFTY50  SENSEX  NASDAQ  DJIA
# SP500     1.00     0.97    0.91    0.98  0.99
# NIFTY50   0.97     1.00    1.00    0.94  0.97
# SENSEX    0.91     1.00    1.00    0.90  0.93
# NASDAQ    0.98     0.94    0.90    1.00  0.97
# DJIA      0.99     0.97    0.93    0.97  1.00

# %%
data.head()
# Out:
#          Date    Open    High     Low   Close
# 0  11/24/2020 3594.52 3642.31 3594.52 3635.41
# 1  11/23/2020 3566.82 3589.81 3552.77 3577.59
# 2  11/20/2020 3579.31 3581.23 3556.85 3557.54
# 3  11/19/2020 3559.41 3585.22 3543.84 3581.87
# 4  11/18/2020 3612.09 3619.09 3567.33 3567.79
